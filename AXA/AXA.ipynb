# %%
import os
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# %ls Tracefile*
# Out:
# Tracefile_nrep-sp-acc-br.csv*           Tracefile-sp-acc-br.csv*
# Tracefile_nrep-sp-acc-br-velremov.csv*  Tracefile-sp-acc-br-nch.csv*

# %%
df = pd.read_csv('Features30-NOSTAND-nreprot.csv', header=None)
df.head()
# Out:
#             0     1             2          3          4         5          6   \
# 0   297.801070   174    781.514854  10.403983   4.794570  3.468090   0.405662
# 1  1152.287398   827  14078.039017  25.212536  17.252499  6.367410  13.993111
# 2  7650.175064  1442  14874.077962  73.642776  10.394184  8.247289   4.599828
# 3  1160.810336   203   1435.743152  13.764977   7.477829  2.753696   6.469168
# 4  5503.689179   730   8771.535530  30.123832  12.199632  8.219877   5.757950
#
#           7          8          9     ...           20   21        22  \
# 0   5.668076   7.581493   4.090215    ...     0.665606   29   361.659
# 1  19.843874  21.976910  18.674439    ...     0.403473  126  6838.730
# 2  10.842556  14.803193  54.105878    ...     0.644429  183  8000.269
# 3   7.757711   8.497193   9.866683    ...     0.387076   47  1248.603
# 4  10.803210  17.069193   8.075848    ...     0.604943   73  7017.104
#
#           23        24        25  26  27        28        29
# ...

# %%
df = df[df.ix[:,0]<80000]

# %%
df = df[df.ix[:,3]<5000]

# %%
df.describe()
# Out:
#                    0              1               2              3   \
# count   547200.000000  547200.000000   547200.000000  547200.000000
# mean      3994.649432     560.801294     5900.972026      19.148475
# std      16082.395522     371.104574    14880.357448      11.661692
# min          0.000000       2.000000        0.100000       0.100000
# 25%        841.705417     264.000000     1702.099625      13.945960
# 50%       2077.876290     454.000000     3711.142197      17.950480
# 75%       5415.973582     776.000000     8169.598803      22.988047
# max    9937696.875599    1773.000000  9948898.381175     249.990745
#
#                   4              5              6              7   \
# count  547200.000000  547200.000000  547200.000000  547200.000000
# mean        9.241907       5.301490       5.081563       9.525817
# std         4.577198       2.226154       4.318940       5.492895
# min         0.038927       0.000000       0.000000       0.000000
# ...

# %%
sns.boxplot(df.ix[:,28]).set_ylim([0,100]) # straight/l
# Out:
# (0, 100)

# %%
sns.boxplot(df.ix[:,3]).set_ylim([0,4000]) # max speed
# Out:
# (0, 4000)

# %%
sns.boxplot(df.ix[:,0]).set_ylim([0,100000]) # trip length
# Out:
# (0, 100000)

# %%
dfdict = {}
driverdir = '../data/drivers/1011'
listtraces = [f for f in os.listdir(driverdir) if f.endswith('csv')]
#print listtraces
for traceID in listtraces:
     dfdict[traceID] = pd.read_csv(driverdir+'/'+traceID)
#df.head()

# %%
for traceID in listtraces:
    plt.plot(dfdict[traceID].x, dfdict[traceID].y)

# %%
dfdict[traceID] = pd.read_csv(driverdir+'/10.csv-nreprot')
dfdict[traceID].columns = ['x', 'y']
dfdict[traceID].head()
# Out:
#       x      y
# 0  0.00   0.00
# 1  0.00  13.38
# 2  0.09  26.57
# 3  1.27  39.02
# 4  1.45  50.86

# %%
dfdict = {}
driverdir = '../data/drivers/1704'
listtraces = [f for f in os.listdir(driverdir) if f.endswith('csv-nreprot')]
for traceID in listtraces:
     dfdict[traceID] = pd.read_csv(driverdir+'/'+traceID)
     dfdict[traceID].columns = ['x', 'y']
     plt.plot(dfdict[traceID].x, dfdict[traceID].y, color='#CCCCCC')
listtraces = [108,200] # [157, 179, 27]
listtraces = [str(num)+'.csv-nreprot' for num in listtraces]
for traceID in listtraces:
     dfdict[traceID] = pd.read_csv(driverdir+'/'+traceID)
     dfdict[traceID].columns = ['x', 'y']
     plt.plot(dfdict[traceID].x, dfdict[traceID].y)
plt.ylim(-1000, 1000) ; plt.xlim(-1000,1000)
# Out:
# (-1000, 1000)
